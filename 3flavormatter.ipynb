# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshara2106/3flavormatter/blob/main/3flavormatter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
#constants
E = np.linspace(0.1, 5, 1000)
L = 295  # baseline in km
del_m_sqrd_31 = 2.507e-3  # in eV^2
del_m_sqrd_21 = 7.41e-5  # in eV^2
theta_12 = np.deg2rad(33.425)
theta_13 = np.deg2rad(8.58)
rho = 2.3  # density in g/cm^3
sin2_2theta_13 = np.sin(2 * theta_13) ** 2
sin2_2theta_12 = np.sin(2 * theta_12) ** 2
alpha = del_m_sqrd_21 / del_m_sqrd_31


A_values = []
P_ee_values = []

for E_value in E:
    delta = (del_m_sqrd_31 * L * 1.27) / E_value
    v = 7.63e-5 * rho * E_value  # matter potential in units of eV^2 / (g/cm^3 * GeV)
    A = v / del_m_sqrd_31
    A_values.append(A)
    P_ee = 1 - (alpha ** 2) * sin2_2theta_12 * (np.sin(delta * A) ** 2) / (A ** 2)- sin2_2theta_13 * (np.sin(delta * (A - 1)) ** 2) / ((A - 1) ** 2)
    P_ee_values.append(P_ee)

plt.plot(E, P_ee_values)
plt.title("Variation of survival probability of $ν_e$ in matter with energy \n (chosen baseline is 295 km)\n")
plt.xlabel("$E_ν$ in GeV")
plt.ylabel("$P^{matter}_{ν_e->ν_e}$")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

E = np.arange(0.1, 5, 0.01)
L = 295  # baseline in km
del_m_sqrd_31 = 2.507e-3  # in eV^2
del_m_sqrd_21 = 7.41e-5  # in eV^2
theta_12 = np.deg2rad(33.425)
theta_13 = np.deg2rad(8.58)
theta_23 = np.deg2rad(42.3)
delta_cp = np.deg2rad(45)
rho = 2.3  # density in g/cm^3

s2_12 = np.sin(2 * theta_12)
c_23 = np.cos(theta_23)
s_13 = np.sin(theta_13)
s_23 = np.sin(theta_23)
s2_23 = np.sin(2 * theta_23)
alpha = del_m_sqrd_21 / del_m_sqrd_31
A_factor = 7.63e-5  # in units of eV^2 / (g/cm^3 * GeV)

A_values = []
P_emu_values = []

for i in range(len(E)):
    delta = (del_m_sqrd_31 * L * 1.27) / E[i]
    v = A_factor * rho * E[i]
    A = v / del_m_sqrd_31
    A_values.append(A)
    term1 = (alpha ** 2) * (s2_12 ** 2) * (c_23 ** 2) * (np.sin(A * delta) ** 2) / (A ** 2)
    term2 = 4 * (s_13 ** 2) * (s_23 ** 2) * (np.sin((A - 1) * delta) ** 2) / ((A - 1) ** 2)
    term3 = 2 * alpha * s_13 * s2_12 * s2_23 * np.cos(delta - delta_cp) * (np.sin(A * delta) / A) * (np.sin((A - 1) * delta) / (A - 1))
    P_emu = term1 + term2 + term3
    P_emu_values.append(P_emu)

plt.plot(E, P_emu_values)
plt.title("Variation of transition probability of $ν_e$ to $ν_μ$ in matter with energy \n (chosen baseline is 295 km)\n")
plt.xlabel("$E_ν$ in GeV")
plt.ylabel("$P^{matter}_{ν_e->ν_μ}$")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

E = np.arange(0.1, 5, 0.01)
L = 295  # baseline in km
del_m_sqrd_31 = 2.507e-3  # in eV^2
del_m_sqrd_32 = 2.507e-3  # in eV^2
del_m_sqrd_21 = 7.41e-5  # in eV^2
theta12 = 33.425
theta13 = 8.58
theta23 = 42.3
c13 = np.cos(np.deg2rad(theta13))
s13 = np.sin(np.deg2rad(theta13))
c12 = np.cos(np.deg2rad(theta12))
s12 = np.sin(np.deg2rad(theta12))
c2_13 = np.cos(np.deg2rad(2*theta13))
c4_13 = np.cos(np.deg2rad(4*theta13))
s2_13 = np.sin(np.deg2rad(2*theta13))
s4_13 = np.sin(np.deg2rad(4*theta13))
c23 = np.cos(np.deg2rad(theta23))
s23 = np.sin(np.deg2rad(theta23))
c2_23 = np.cos(np.deg2rad(2*theta23))
c4_23 = np.cos(np.deg2rad(4*theta23))
s2_23 = np.sin(np.deg2rad(2*theta23))
s4_23 = np.sin(np.deg2rad(4*theta23))
s2_12 = np.sin(np.deg2rad(2 * theta12))
c2_12 = np.cos(np.deg2rad(2 * theta12))
delta_cp = np.deg2rad(45)
cdelta_cp = np.cos(np.deg2rad( delta_cp))
sdelta_cp = np.sin(np.deg2rad( delta_cp))

rho = 2.3  # density in g/cm^3
alpha = del_m_sqrd_21 / del_m_sqrd_31
A_factor = 7.63e-5  # in units of eV^2 / (g/cm^3 * GeV)

A_values = []
A_values_a = []
P_emu_values_m = []
P_antiemu_values_v = []
P_antiemu_values_m = []
P_emu_values_v = []

for i in range(len(E)):
    delta = (del_m_sqrd_31 * L * 1.27) / E[i]
    v = A_factor * rho * E[i]
    A = v / del_m_sqrd_31
    A_values.append(A)
    term1 = (alpha ** 2) * (s2_12 ** 2) * (c23 ** 2) * (np.sin(A * delta) ** 2) / (A ** 2)
    term2 = 4 * (s13 ** 2) * (s23 ** 2) * (np.sin((A - 1) * delta) ** 2) / ((A - 1) ** 2)
    term3 = 2 * alpha * s13 * s2_12 * s2_23 * np.cos(delta - delta_cp) * (np.sin(A * delta) / A) * (np.sin((A - 1) * delta) / (A - 1))
    P_emu_m = term1 + term2 + term3
    P_emu_values_m.append(P_emu_m)
    P_antiemu_v = -4*(-0.25*s2_12*c13**2*(s2_12*(c23**2-s23**2*s13**2)+c2_12*s2_23*s13*cdelta_cp)*(np.sin((del_m_sqrd_21*5.064*L)/(4*E[i])))**2-(c12*s23*c13**2*s13*(c12*s23*s13+s12*c23*cdelta_cp))*(np.sin((del_m_sqrd_31*5.064*L)/(4*E[i])))**2-(s12*s23*c13**2*s13*(s12*s13*s23-c12*c23*cdelta_cp))*(np.sin((del_m_sqrd_32*5.064*L)/(4*E[i])))**2)-2*(c12*s23*s13*sdelta_cp*s12*c23*c2_13)*(-np.sin((del_m_sqrd_31*5.064*L)/(2*E[i]))+np.sin((del_m_sqrd_32*5.064*L)/(2*E[i]))+np.sin((del_m_sqrd_21*5.064*L)/(2*E[i])))
    P_antiemu_values_v.append(P_antiemu_v)
    v_a = -(A_factor * rho * E[i])
    A_a = v_a / del_m_sqrd_31
    A_values_a.append(A_a)
    term1a = (alpha ** 2) * (s2_12 ** 2) * (c23 ** 2) * (np.sin(A_a * delta) ** 2) / (A_a ** 2)
    term2a = 4 * (s13 ** 2) * (s23 ** 2) * (np.sin((A_a - 1) * delta) ** 2) / ((A_a - 1) ** 2)
    term3a = 2 * alpha * s13 * s2_12 * s2_23 * np.cos(delta - delta_cp) * (np.sin(A_a * delta) / A_a) * (np.sin((A_a - 1) * delta) / (A_a - 1))
    P_antiemu_m = term1a + term2a + term3a
    P_antiemu_values_m.append(P_antiemu_m)
    P_emu_v = -4*((-0.25*s2_12*c13**2*(s2_12*(c23**2-s23**2*s13**2)+c2_12*s2_23*s13*cdelta_cp))*(np.sin((del_m_sqrd_21*5.064*L)/(4*E[i])))**2-c12*s23*c13**2*s13*(c12*s23*s13+s12*c23*cdelta_cp)*(np.sin((del_m_sqrd_31*5.064*L)/(4*E[i])))**2-s12*s23*c13**2*s13*(s12*s23*s13-c12*c23*cdelta_cp)*(np.sin((del_m_sqrd_32*5.064*L)/(4*E[i])))**2)+2*(c12*s23*s13*sdelta_cp*s12*c23*c2_13)*(np.sin((del_m_sqrd_31*5.064*L)/(2*E[i]))-np.sin((del_m_sqrd_32*5.064*L)/(2*E[i]))-np.sin((del_m_sqrd_21*5.064*L)/(2*E[i])))
    P_emu_values_v.append(P_emu_v)

plt.plot(E,P_antiemu_values_m,label='$\overline{P}^{matter}_{ν_e->ν_μ}$')
plt.plot(E,P_emu_values_m,label='$P^{matter}_{ν_e->ν_μ}$')
plt.plot(E,P_emu_values_v,label='$P^{vacuum}_{ν_e->ν_μ}$')
plt.plot(E,P_antiemu_values_v,label='$\overline{P}^{vacuum}_{ν_e->ν_μ}$')
plt.title("Variation of transition probability of $ν_e$ to $ν_μ$ in matter and vacuum with energy \n (chosen baseline is 295 km)\n")
plt.xlabel("$E_ν$ in GeV")
plt.ylabel("Transition probability")
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

E = np.linspace(0.1, 5, 1000)
L = 295
del_m_sqrd_31 = 2.507e-3  # in eV^2
del_m_sqrd_21 = 7.41e-5  # in eV^2
theta12 = np.deg2rad(33.425)
theta13 = np.deg2rad(8.58)
theta23 = np.deg2rad(45)
delta_cp = np.deg2rad(0)
rho = 2.3  # density in g/cm^3

sin2_2theta_13 = np.sin(2 * theta13) ** 2
sin2_2theta_12 = np.sin(2 * theta12) ** 2
alpha = del_m_sqrd_21 / del_m_sqrd_31
c13 = np.cos(theta13)
s13 = np.sin(theta13)
s2_12 = np.sin(2 * theta12)
c12 = np.cos(theta12)
s12 = np.sin(theta12)

A_values = []
A_a_values = []
P_ee_values_m = []
P_antiee_values_m = []
P_ee_values_v = []
P_antiee_values_v = []

for E_value in E:
    delta = (del_m_sqrd_31 * L * 1.27) / E_value
    v = 7.63e-5 * rho * E_value
    A = v / del_m_sqrd_31
    A_values.append(A)

    P_ee_m = 1 - (alpha ** 2) * sin2_2theta_12 * (np.sin(delta * A) ** 2) / (A ** 2) - sin2_2theta_13 * (np.sin(delta * (A - 1)) ** 2) / ((A - 1) ** 2)
    P_ee_values_m.append(P_ee_m)

    P_ee_v = 1 - (s2_12**2 * c13**4 * (np.sin((del_m_sqrd_21 * L * 5.064) / (4 * E_value)))**2
                  + s12**2 * sin2_2theta_13 * (np.sin((del_m_sqrd_31 * L * 5.064) / (4 * E_value)))**2)
    P_ee_values_v.append(P_ee_v)

    v_a = -(7.63e-5 * rho * E_value)
    A_a = v_a / del_m_sqrd_31
    A_a_values.append(A_a)

    P_antiee_m = 1 - (alpha ** 2) * sin2_2theta_12 * (np.sin(delta * A_a) ** 2) / (A_a ** 2) - sin2_2theta_13 * (np.sin(delta * (A_a - 1)) ** 2) / ((A_a - 1) ** 2)
    P_antiee_values_m.append(P_antiee_m)

    P_antiee_v = 1 - (s2_12**2 * c13**4 * (np.sin((del_m_sqrd_21 * L * 5.064) / (4 * E_value)))**2
                      + s12**2 * sin2_2theta_13 * (np.sin((del_m_sqrd_31 * L * 5.064) / (4 * E_value)))**2)
    P_antiee_values_v.append(P_antiee_v)

# Plotting
plt.plot(E, P_ee_values_m, label='$P^{matter}_{ν_e->ν_e}$')
plt.plot(E, P_ee_values_v, label='$P^{vacuum}_{ν_e->ν_e}$')
plt.plot(E, P_antiee_values_v, label='$\\overline{P}^{vacuum}_{ν_e->ν_e}$')
plt.plot(E, P_antiee_values_m, label='$\\overline{P}^{matter}_{ν_e->ν_e}$')
plt.title("Variation of survival probability of $ν_e$ in matter and vacuum with energy \n (chosen baseline is 295 km)\n")
plt.xlabel("$E_ν$ in GeV")
plt.ylabel("Survival probability")
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

E = np.linspace(0.1, 5, 1000)
L = 295
del_m_sqrd_31 = 2.507e-3  # in eV^2
del_m_sqrd_21 = 7.41e-5  # in eV^2
theta12 = np.deg2rad(33.425)
theta13 = np.deg2rad(8.58)
theta23 = np.deg2rad(45)
delta_cp = np.deg2rad(0)
rho = 2.3  # density in g/cm^3

sin2_2theta_13 = np.sin(2 * theta13) ** 2
sin2_2theta_12 = np.sin(2 * theta12) ** 2
sin2_2theta_23 = np.sin(2 * theta23)**2
cos2_2theta_23 = np.cos(2 * theta23)**2
alpha = del_m_sqrd_21 / del_m_sqrd_31
c13 = np.cos(theta13)
s13 = np.sin(theta13)
s2_12 = np.sin(2 * theta12)
s4_12 = np.sin(4*theta12)
c12 = np.cos(theta12)
s12 = np.sin(theta12)
c23 = np.cos(theta23)

A_values = []
A_a_values = []
P_mumu_values_m = []
P_antimumu_values_m = []
P_mumu_values_v = []
P_antimumu_values_v = []

for E_value in E:
    delta = (del_m_sqrd_31 * L * 1.27) / E_value
    v = 7.63e-5 * rho * E_value
    A = v / del_m_sqrd_31
    A_values.append(A)

    term1 = sin2_2theta_23* (np.sin(delta)**2)
    term2 = alpha*(c12**2)*sin2_2theta_23*delta*(np.sin(2*delta))
    term3 = alpha**2*(sin2_2theta_12)*(c23**2)*((np.sin(A*delta)**2)/(A**2))
    term4 = (alpha**2)*(c12**4)*(sin2_2theta_23)*(delta**2)*(np.cos(2*delta))
    term5 = (1/(2*A))*(A**2)*(sin2_2theta_12)*(sin2_2theta_23)*(((np.sin(delta))*((np.sin(A*delta))/A)*(np.cos(A-1))*delta)-((delta/2)*(np.sin(2*delta))))
    term6 = 4*(s13**2)*(s23**2)*((np.sin((A-1)*delta)**2)/((A-1)**2))
    term7 = (2/(A-1))*(s13**2)*sin2_2theta_23*(((np.sin(delta))*(np.cos(A*delta))*((np.sin((A-1)*delta))/(A-1)))-((A/2)*delta*(np.sin(2*delta))))
    term8 = 2*A*s13*sin2_2theta_12*sin2_2theta_23*np.cos(delta_cp)*np.cos(delta)*((np.sin(A*delta))/A)*((np.sin((A-1)*delta))/(A-1))
    term9 = (2/(A-1))*A*s13*sin2_2theta_12*sin2_2theta_23*cos2_2theta_23*(np.cos(delta_cp))*(np.sin(delta))*(A*(np.sin(delta))-(((np.sin(A*delta))/A)*(np.cos(A-1))*delta))
    P_mumu_m = 1 - term1+term2-term3-term4+term5-term6-term7-term8+term9
    P_mumu_values_m.append(P_mumu_m)

    P_mumu_v = 1 - ((((s2_12**2*(c23**4 + (s23**4*s13**2))) + ((1 - (0.5*s2_12**2))*s2_23**2*s13**2) + (s4_12*s2_23*(c23**2 - (s23**2*s13**2))*s13*cdelta_cp)-(s2_12**2*s2_23**2*s13**2*cdelta_cp**2))*(np.sin((del_m_sqrd_21*5.08*L)/(4*E_value)))**2) + (4*(((s23**2*c13**2*((s12**2*c23**2) + (c12**2*s23**2*s13**2) + (0.5*s2_12*s2_23*s13**2*cdelta_cp**2)))*(np.sin((del_m_sqrd_31*5.08*L)/(4*E_value)))**2) + ((s23**2*c13**2*((c12**2*c23**2) + (s12**2*s23**2*s13**2) - (0.5*s2_12*s2_23*s13**2*cdelta_cp**2)))*((np.sin((del_m_sqrd_32*5.08*L)/(4*E_value)))**2)))))
    P_mumu_values_v.append(P_mumu_v)

    v_a = -(7.63e-5 * rho * E_value)
    A_a = v_a / del_m_sqrd_31
    A_a_values.append(A_a)

    P_antimumu_m = 1 - (alpha ** 2) * sin2_2theta_12 * (np.sin(delta * A_a) ** 2) / (A_a ** 2) - sin2_2theta_13 * (np.sin(delta * (A_a - 1)) ** 2) / ((A_a - 1) ** 2)
    P_antimumu_values_m.append(P_antimumu_m)

    P_antimumu_v = 1 - ((((s2_12**2*(c23**4 + (s23**4*s13**2))) + ((1 - (0.5*s2_12**2))*s2_23**2*s13**2) + (s4_12*s2_23*(c23**2 - (s23**2*s13**2))*s13*cdelta_cp)-(s2_12**2*s2_23**2*s13**2*cdelta_cp**2))*(np.sin((del_m_sqrd_21*5.08*L)/(4*E_value)))**2) + (4*(((s23**2*c13**2*((s12**2*c23**2) + (c12**2*s23**2*s13**2) + (0.5*s2_12*s2_23*s13**2*cdelta_cp**2)))*(np.sin((del_m_sqrd_31*5.08*L)/(4*E_value)))**2) + ((s23**2*c13**2*((c12**2*c23**2) + (s12**2*s23**2*s13**2) - (0.5*s2_12*s2_23*s13**2*cdelta_cp**2)))*((np.sin((del_m_sqrd_32*5.08*L)/(4*E_value)))**2)))))
    P_antimumu_values_v.append(P_antimumu_v)

# Plotting
plt.plot(E, P_mumu_values_m, label='$P^{matter}_{ν_μ->ν_μ}$')
plt.plot(E, P_mumu_values_v, label='$P^{vacuum}_{ν_μ->ν_μ}$')
plt.plot(E, P_antimumu_values_v, label='$\\overline{P}^{vacuum}_{ν_μ->ν_μ}$')
plt.plot(E, P_antimumu_values_m, label='$\\overline{P}^{matter}_{ν_μ->ν_μ}$')
plt.title("Variation of survival probability of $ν_μ$ in matter and vacuum with energy \n (chosen baseline is 295 km)\n")
plt.xlabel("$E_ν$ in GeV")
plt.ylabel("Survival probability")
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

E = np.arange(0.1, 4.5, 0.01)
L = 810  # baseline in km
del_m_sqrd_31 = 2.507e-3  # in eV^2
del_m_sqrd_32 = 2.507e-3  # in eV^2
del_m_sqrd_21 = 7.41e-5  # in eV^2
theta12 = 33.425
theta13 = 8.58
theta23 = 42.3
c13 = np.cos(np.deg2rad(theta13))
s13 = np.sin(np.deg2rad(theta13))
c12 = np.cos(np.deg2rad(theta12))
s12 = np.sin(np.deg2rad(theta12))
c2_13 = np.cos(np.deg2rad(2*theta13))
c4_13 = np.cos(np.deg2rad(4*theta13))
s2_13 = np.sin(np.deg2rad(2*theta13))
s4_13 = np.sin(np.deg2rad(4*theta13))
c23 = np.cos(np.deg2rad(theta23))
s23 = np.sin(np.deg2rad(theta23))
c2_23 = np.cos(np.deg2rad(2*theta23))
c4_23 = np.cos(np.deg2rad(4*theta23))
s2_23 = np.sin(np.deg2rad(2*theta23))
s4_23 = np.sin(np.deg2rad(4*theta23))
s2_12 = np.sin(np.deg2rad(2 * theta12))
c2_12 = np.cos(np.deg2rad(2 * theta12))
delta_cp = np.deg2rad(45)
cdelta_cp = np.cos(np.deg2rad( delta_cp))
sdelta_cp = np.sin(np.deg2rad( delta_cp))

rho = 2.84  # density in g/cm^3
alpha = del_m_sqrd_21 / del_m_sqrd_31
A_factor = 7.63e-5  # in units of eV^2 / (g/cm^3 * GeV)

A_values = []
A_values_a = []
P_emu_values_m = []
P_antiemu_values_v = []
P_antiemu_values_m = []
P_emu_values_v = []

for i in range(len(E)):
    delta = (del_m_sqrd_31 * L * 1.27) / E[i]
    v = A_factor * rho * E[i]
    A = v / del_m_sqrd_31
    A_values.append(A)
    term1 = (alpha ** 2) * (s2_12 ** 2) * (c23 ** 2) * (np.sin(A * delta) ** 2) / (A ** 2)
    term2 = 4 * (s13 ** 2) * (s23 ** 2) * (np.sin((A - 1) * delta) ** 2) / ((A - 1) ** 2)
    term3 = 2 * alpha * s13 * s2_12 * s2_23 * np.cos(delta - delta_cp) * (np.sin(A * delta) / A) * (np.sin((A - 1) * delta) / (A - 1))
    P_emu_m = term1 + term2 + term3
    P_emu_values_m.append(P_emu_m)
    P_antiemu_v = -4*(-0.25*s2_12*c13**2*(s2_12*(c23**2-s23**2*s13**2)+c2_12*s2_23*s13*cdelta_cp)*(np.sin((del_m_sqrd_21*5.064*L)/(4*E[i])))**2-(c12*s23*c13**2*s13*(c12*s23*s13+s12*c23*cdelta_cp))*(np.sin((del_m_sqrd_31*5.064*L)/(4*E[i])))**2-(s12*s23*c13**2*s13*(s12*s13*s23-c12*c23*cdelta_cp))*(np.sin((del_m_sqrd_32*5.064*L)/(4*E[i])))**2)-2*(c12*s23*s13*sdelta_cp*s12*c23*c2_13)*(-np.sin((del_m_sqrd_31*5.064*L)/(2*E[i]))+np.sin((del_m_sqrd_32*5.064*L)/(2*E[i]))+np.sin((del_m_sqrd_21*5.064*L)/(2*E[i])))
    P_antiemu_values_v.append(P_antiemu_v)
    v_a = -(A_factor * rho * E[i])
    A_a = v_a / del_m_sqrd_31
    A_values_a.append(A_a)
    term1a = (alpha ** 2) * (s2_12 ** 2) * (c23 ** 2) * (np.sin(A_a * delta) ** 2) / (A_a ** 2)
    term2a = 4 * (s13 ** 2) * (s23 ** 2) * (np.sin((A_a - 1) * delta) ** 2) / ((A_a - 1) ** 2)
    term3a = 2 * alpha * s13 * s2_12 * s2_23 * np.cos(delta - delta_cp) * (np.sin(A_a * delta) / A_a) * (np.sin((A_a - 1) * delta) / (A_a - 1))
    P_antiemu_m = term1a + term2a + term3a
    P_antiemu_values_m.append(P_antiemu_m)
    P_emu_v = -4*((-0.25*s2_12*c13**2*(s2_12*(c23**2-s23**2*s13**2)+c2_12*s2_23*s13*cdelta_cp))*(np.sin((del_m_sqrd_21*5.064*L)/(4*E[i])))**2-c12*s23*c13**2*s13*(c12*s23*s13+s12*c23*cdelta_cp)*(np.sin((del_m_sqrd_31*5.064*L)/(4*E[i])))**2-s12*s23*c13**2*s13*(s12*s23*s13-c12*c23*cdelta_cp)*(np.sin((del_m_sqrd_32*5.064*L)/(4*E[i])))**2)+2*(c12*s23*s13*sdelta_cp*s12*c23*c2_13)*(np.sin((del_m_sqrd_31*5.064*L)/(2*E[i]))-np.sin((del_m_sqrd_32*5.064*L)/(2*E[i]))-np.sin((del_m_sqrd_21*5.064*L)/(2*E[i])))
    P_emu_values_v.append(P_emu_v)

plt.plot(E,P_antiemu_values_m,label='$\overline{P}^{matter}_{ν_e->ν_μ}$')
plt.plot(E,P_emu_values_m,label='$P^{matter}_{ν_e->ν_μ}$')
plt.plot(E,P_emu_values_v,label='$P^{vacuum}_{ν_e->ν_μ}$')
plt.plot(E,P_antiemu_values_v,label='$\overline{P}^{vacuum}_{ν_e->ν_μ}$')
plt.title("Variation of transition probability of $ν_e$ to $ν_μ$ in matter and vacuum with energy \n (chosen baseline is 810 km)\n")
plt.xlabel("$E_ν$ in GeV")
plt.ylabel("Transition probability")
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

E = np.arange(0.1, 5, 0.01)
L = 1300  # baseline in km
del_m_sqrd_31 = 2.507e-3  # in eV^2
del_m_sqrd_32 = 2.507e-3  # in eV^2
del_m_sqrd_21 = 7.41e-5  # in eV^2
theta12 = 33.425
theta13 = 8.58
theta23 = 42.3
c13 = np.cos(np.deg2rad(theta13))
s13 = np.sin(np.deg2rad(theta13))
c12 = np.cos(np.deg2rad(theta12))
s12 = np.sin(np.deg2rad(theta12))
c2_13 = np.cos(np.deg2rad(2*theta13))
c4_13 = np.cos(np.deg2rad(4*theta13))
s2_13 = np.sin(np.deg2rad(2*theta13))
s4_13 = np.sin(np.deg2rad(4*theta13))
c23 = np.cos(np.deg2rad(theta23))
s23 = np.sin(np.deg2rad(theta23))
c2_23 = np.cos(np.deg2rad(2*theta23))
c4_23 = np.cos(np.deg2rad(4*theta23))
s2_23 = np.sin(np.deg2rad(2*theta23))
s4_23 = np.sin(np.deg2rad(4*theta23))
s2_12 = np.sin(np.deg2rad(2 * theta12))
c2_12 = np.cos(np.deg2rad(2 * theta12))
delta_cp = np.deg2rad(45)
cdelta_cp = np.cos(np.deg2rad( delta_cp))
sdelta_cp = np.sin(np.deg2rad( delta_cp))

rho = 3  # density in g/cm^3
alpha = del_m_sqrd_21 / del_m_sqrd_31
A_factor = 7.63e-5  # in units of eV^2 / (g/cm^3 * GeV)

A_values = []
A_values_a = []
P_emu_values_m = []
P_antiemu_values_v = []
P_antiemu_values_m = []
P_emu_values_v = []

for i in range(len(E)):
    delta = (del_m_sqrd_31 * L * 1.27) / E[i]
    v = A_factor * rho * E[i]
    A = v / del_m_sqrd_31
    A_values.append(A)
    term1 = (alpha ** 2) * (s2_12 ** 2) * (c23 ** 2) * (np.sin(A * delta) ** 2) / (A ** 2)
    term2 = 4 * (s13 ** 2) * (s23 ** 2) * (np.sin((A - 1) * delta) ** 2) / ((A - 1) ** 2)
    term3 = 2 * alpha * s13 * s2_12 * s2_23 * np.cos(delta - delta_cp) * (np.sin(A * delta) / A) * (np.sin((A - 1) * delta) / (A - 1))
    P_emu_m = term1 + term2 + term3
    P_emu_values_m.append(P_emu_m)
    P_antiemu_v = -4*(-0.25*s2_12*c13**2*(s2_12*(c23**2-s23**2*s13**2)+c2_12*s2_23*s13*cdelta_cp)*(np.sin((del_m_sqrd_21*5.064*L)/(4*E[i])))**2-(c12*s23*c13**2*s13*(c12*s23*s13+s12*c23*cdelta_cp))*(np.sin((del_m_sqrd_31*5.064*L)/(4*E[i])))**2-(s12*s23*c13**2*s13*(s12*s13*s23-c12*c23*cdelta_cp))*(np.sin((del_m_sqrd_32*5.064*L)/(4*E[i])))**2)-2*(c12*s23*s13*sdelta_cp*s12*c23*c2_13)*(-np.sin((del_m_sqrd_31*5.064*L)/(2*E[i]))+np.sin((del_m_sqrd_32*5.064*L)/(2*E[i]))+np.sin((del_m_sqrd_21*5.064*L)/(2*E[i])))
    P_antiemu_values_v.append(P_antiemu_v)
    v_a = -(A_factor * rho * E[i])
    A_a = v_a / del_m_sqrd_31
    A_values_a.append(A_a)
    term1a = (alpha ** 2) * (s2_12 ** 2) * (c23 ** 2) * (np.sin(A_a * delta) ** 2) / (A_a ** 2)
    term2a = 4 * (s13 ** 2) * (s23 ** 2) * (np.sin((A_a - 1) * delta) ** 2) / ((A_a - 1) ** 2)
    term3a = 2 * alpha * s13 * s2_12 * s2_23 * np.cos(delta - delta_cp) * (np.sin(A_a * delta) / A_a) * (np.sin((A_a - 1) * delta) / (A_a - 1))
    P_antiemu_m = term1a + term2a + term3a
    P_antiemu_values_m.append(P_antiemu_m)
    P_emu_v = -4*((-0.25*s2_12*c13**2*(s2_12*(c23**2-s23**2*s13**2)+c2_12*s2_23*s13*cdelta_cp))*(np.sin((del_m_sqrd_21*5.064*L)/(4*E[i])))**2-c12*s23*c13**2*s13*(c12*s23*s13+s12*c23*cdelta_cp)*(np.sin((del_m_sqrd_31*5.064*L)/(4*E[i])))**2-s12*s23*c13**2*s13*(s12*s23*s13-c12*c23*cdelta_cp)*(np.sin((del_m_sqrd_32*5.064*L)/(4*E[i])))**2)+2*(c12*s23*s13*sdelta_cp*s12*c23*c2_13)*(np.sin((del_m_sqrd_31*5.064*L)/(2*E[i]))-np.sin((del_m_sqrd_32*5.064*L)/(2*E[i]))-np.sin((del_m_sqrd_21*5.064*L)/(2*E[i])))
    P_emu_values_v.append(P_emu_v)

plt.plot(E,P_antiemu_values_m,label='$\overline{P}^{matter}_{ν_e->ν_μ}$')
plt.plot(E,P_emu_values_m,label='$P^{matter}_{ν_e->ν_μ}$')
plt.plot(E,P_emu_values_v,label='$P^{vacuum}_{ν_e->ν_μ}$')
plt.plot(E,P_antiemu_values_v,label='$\overline{P}^{vacuum}_{ν_e->ν_μ}$')
plt.title("Variation of transition probability of $ν_e$ to $ν_μ$ in matter and vacuum with energy \n (chosen baseline is 1300 km)\n")
plt.xlabel("$E_ν$ in GeV")
plt.ylabel("Transition probability")
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

E = np.arange(0.1, 5, 0.01)
L = 7000  # baseline in km
del_m_sqrd_31 = 2.507e-3  # in eV^2
del_m_sqrd_32 = 2.507e-3  # in eV^2
del_m_sqrd_21 = 7.41e-5  # in eV^2
theta12 = 33.425
theta13 = 8.58
theta23 = 42.3
c13 = np.cos(np.deg2rad(theta13))
s13 = np.sin(np.deg2rad(theta13))
c12 = np.cos(np.deg2rad(theta12))
s12 = np.sin(np.deg2rad(theta12))
c2_13 = np.cos(np.deg2rad(2*theta13))
c4_13 = np.cos(np.deg2rad(4*theta13))
s2_13 = np.sin(np.deg2rad(2*theta13))
s4_13 = np.sin(np.deg2rad(4*theta13))
c23 = np.cos(np.deg2rad(theta23))
s23 = np.sin(np.deg2rad(theta23))
c2_23 = np.cos(np.deg2rad(2*theta23))
c4_23 = np.cos(np.deg2rad(4*theta23))
s2_23 = np.sin(np.deg2rad(2*theta23))
s4_23 = np.sin(np.deg2rad(4*theta23))
s2_12 = np.sin(np.deg2rad(2 * theta12))
c2_12 = np.cos(np.deg2rad(2 * theta12))
delta_cp = np.deg2rad(45)
cdelta_cp = np.cos(np.deg2rad( delta_cp))
sdelta_cp = np.sin(np.deg2rad( delta_cp))

rho = 3.5  # density in g/cm^3
alpha = del_m_sqrd_21 / del_m_sqrd_31
A_factor = 7.63e-5  # in units of eV^2 / (g/cm^3 * GeV)

A_values = []
A_values_a = []
P_emu_values_m = []
P_antiemu_values_v = []
P_antiemu_values_m = []
P_emu_values_v = []

for i in range(len(E)):
    delta = (del_m_sqrd_31 * L * 1.27) / E[i]
    v = A_factor * rho * E[i]
    A = v / del_m_sqrd_31
    A_values.append(A)
    term1 = (alpha ** 2) * (s2_12 ** 2) * (c23 ** 2) * (np.sin(A * delta) ** 2) / (A ** 2)
    term2 = 4 * (s13 ** 2) * (s23 ** 2) * (np.sin((A - 1) * delta) ** 2) / ((A - 1) ** 2)
    term3 = 2 * alpha * s13 * s2_12 * s2_23 * np.cos(delta - delta_cp) * (np.sin(A * delta) / A) * (np.sin((A - 1) * delta) / (A - 1))
    P_emu_m = term1 + term2 + term3
    P_emu_values_m.append(P_emu_m)
    P_antiemu_v = -4*(-0.25*s2_12*c13**2*(s2_12*(c23**2-s23**2*s13**2)+c2_12*s2_23*s13*cdelta_cp)*(np.sin((del_m_sqrd_21*5.064*L)/(4*E[i])))**2-(c12*s23*c13**2*s13*(c12*s23*s13+s12*c23*cdelta_cp))*(np.sin((del_m_sqrd_31*5.064*L)/(4*E[i])))**2-(s12*s23*c13**2*s13*(s12*s13*s23-c12*c23*cdelta_cp))*(np.sin((del_m_sqrd_32*5.064*L)/(4*E[i])))**2)-2*(c12*s23*s13*sdelta_cp*s12*c23*c2_13)*(-np.sin((del_m_sqrd_31*5.064*L)/(2*E[i]))+np.sin((del_m_sqrd_32*5.064*L)/(2*E[i]))+np.sin((del_m_sqrd_21*5.064*L)/(2*E[i])))
    P_antiemu_values_v.append(P_antiemu_v)
    v_a = -(A_factor * rho * E[i])
    A_a = v_a / del_m_sqrd_31
    A_values_a.append(A_a)
    term1a = (alpha ** 2) * (s2_12 ** 2) * (c23 ** 2) * (np.sin(A_a * delta) ** 2) / (A_a ** 2)
    term2a = 4 * (s13 ** 2) * (s23 ** 2) * (np.sin((A_a - 1) * delta) ** 2) / ((A_a - 1) ** 2)
    term3a = 2 * alpha * s13 * s2_12 * s2_23 * np.cos(delta - delta_cp) * (np.sin(A_a * delta) / A_a) * (np.sin((A_a - 1) * delta) / (A_a - 1))
    P_antiemu_m = term1a + term2a + term3a
    P_antiemu_values_m.append(P_antiemu_m)
    P_emu_v = -4*((-0.25*s2_12*c13**2*(s2_12*(c23**2-s23**2*s13**2)+c2_12*s2_23*s13*cdelta_cp))*(np.sin((del_m_sqrd_21*5.064*L)/(4*E[i])))**2-c12*s23*c13**2*s13*(c12*s23*s13+s12*c23*cdelta_cp)*(np.sin((del_m_sqrd_31*5.064*L)/(4*E[i])))**2-s12*s23*c13**2*s13*(s12*s23*s13-c12*c23*cdelta_cp)*(np.sin((del_m_sqrd_32*5.064*L)/(4*E[i])))**2)+2*(c12*s23*s13*sdelta_cp*s12*c23*c2_13)*(np.sin((del_m_sqrd_31*5.064*L)/(2*E[i]))-np.sin((del_m_sqrd_32*5.064*L)/(2*E[i]))-np.sin((del_m_sqrd_21*5.064*L)/(2*E[i])))
    P_emu_values_v.append(P_emu_v)

plt.plot(E,P_antiemu_values_m,label='$\overline{P}^{matter}_{ν_e->ν_μ}$')
plt.plot(E,P_emu_values_m,label='$P^{matter}_{ν_e->ν_μ}$')
plt.plot(E,P_emu_values_v,label='$P^{vacuum}_{ν_e->ν_μ}$')
plt.plot(E,P_antiemu_values_v,label='$\overline{P}^{vacuum}_{ν_e->ν_μ}$')
plt.title("Variation of transition probability of $ν_e$ to $ν_μ$ in matter and vacuum with energy \n (chosen baseline is 7000 km)\n")
plt.xlabel("$E_ν$ in GeV")
plt.ylabel("Transition probability")
plt.legend()
plt.tight_layout()
plt.show()
